# %% [markdown]
# Loading the Dataset and Loading All The Libraries

# %%
import pandas as pd
import numpy as np 
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS
import wordcloud
from scipy.stats import zscore


# Read the CSV file into a pandas DataFrame
df = pd.read_csv("/content/disney_plus_shows.csv")


# Display the loaded data
display(df)
# Out:
#        imdb_id                                       title  \
# 0    tt0147800                  10 Things I Hate About You
# 1    tt7019028                        101 Dalmatian Street
# 2    tt0115433                              101 Dalmatians
# 3    tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4    tt0211181                              102 Dalmatians
# ..         ...                                         ...
# 987  tt3544734                                      Zapped
# 988  tt0186726             Zenon: Girl of the 21st Century
# 989  tt0271271                           Zenon: The Zequel
# 990  tt0379060                                   Zenon: Z3
# 991  tt2948356                                    Zootopia
#
#                                                   plot    type  rated   year  \
# 0    A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1    This series follows the lives of Delilah and D...  series    NaN  2018–
# 2    An evil high-fashion designer plots to steal D...   movie      G   1996
# 3    Being one of 101 takes its toll on Patch, who ...   movie      G   2002
# 4    Cruella DeVil gets out of prison and goes afte...   movie      G   2000
# ..                                                 ...     ...    ...    ...
# 987  When Zoey's mom remarries, Zoey finds it hard ...   movie   TV-G   2014
# 988  An inquisitive teenager pries into suspected d...   movie   TV-G   1999
# 989  A mischievous fifteen-year-old girl living on ...   movie   TV-G   2001
# 990  The heroine sets out to win an important compe...   movie   TV-G   2004
# 991  In a city of anthropomorphic animals, a rookie...   movie     PG   2016
#
#      released_at           added_at  runtime  \
# 0    31 Mar 1999  November 12, 2019   97 min
# 1    25 Mar 2019  February 28, 2020      NaN
# 2    27 Nov 1996  November 12, 2019  103 min
# 3    21 Jan 2003  November 12, 2019   74 min
# 4    22 Nov 2000  November 12, 2019  100 min
# ..           ...                ...      ...
# 987  23 Jun 2014  November 12, 2019  102 min
# 988  23 Jan 1999  November 12, 2019   97 min
# 989  12 Jan 2001  November 12, 2019  100 min
# 990  11 Jun 2004  November 12, 2019   81 min
# 991  04 Mar 2016  November 12, 2019  108 min
#
#                                                  genre  \
# 0                               Comedy, Drama, Romance
# 1                            Animation, Comedy, Family
# 2                     Adventure, Comedy, Crime, Family
# 3        Animation, Adventure, Comedy, Family, Musical
# 4                            Adventure, Comedy, Family
# ..                                                 ...
# 987                            Comedy, Family, Fantasy
# 988                  Adventure, Comedy, Family, Sci-Fi
# 989                  Comedy, Family, Adventure, Sci-Fi
# 990                  Adventure, Comedy, Family, Sci-Fi
# 991  Animation, Adventure, Comedy, Crime, Family, M...
#
#                                               director  \
# 0                                           Gil Junger
# 1                                                  NaN
# 2                                        Stephen Herek
# 3                            Jim Kammerud, Brian Smith
# 4                                           Kevin Lima
# ..                                                 ...
# 987                                      Peter DeLuise
# 988                                    Kenneth Johnson
# 989                                         Manny Coto
# 990                                         Steve Rash
# 991  Byron Howard, Rich Moore, Jared Bush(co-director)
#
#                                                 writer  \
# 0                        Karen McCullah, Kirsten Smith
# 1                                                  NaN
# 2        Dodie Smith (novel), John Hughes (screenplay)
# 3    Jim Kammerud (story), Dan Root (story), Garret...
# 4    Dodie Smith (novel), Kristen Buckley (story), ...
# ..                                                 ...
# 987  Leslie Margolis (based on the novel "Boys Are ...
# 988  Marilyn Sadler (book), Roger Bollen (book), St...
# 989  Marilyn Sadler (book), Roger Bollen (book), St...
# 990  Marilyn Sadler (character from the book "Zenon...
# 991  Byron Howard (story by), Rich Moore (story by)...
#
#                                                 actors          language  \
# 0    Heath Ledger, Julia Stiles, Joseph Gordon-Levi...   English, French
# 1    Josh Brener, Michaela Dietz, Bert Davis, Abiga...           English
# 2    Glenn Close, Jeff Daniels, Joely Richardson, J...  English, Spanish
# 3    Barry Bostwick, Jason Alexander, Martin Short,...           English
# 4    Glenn Close, Gérard Depardieu, Ioan Gruffudd, ...           English
# ..                                                 ...               ...
# 987  Zendaya, Chanelle Peloso, Spencer Boldman, Emi...           English
# 988  Kirsten Storms, Raven-Symoné, Stuart Pankin, H...           English
# 989  Kirsten Storms, Shadia Simmons, Lauren Maltby,...           English
# 990  Kirsten Storms, Lauren Maltby, Alyson Morgan, ...           English
# 991  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...           English
#
#               country                                             awards  \
# 0                 USA                           2 wins & 13 nominations.
# 1     UK, USA, Canada                                                NaN
# 2             USA, UK  Nominated for 1 Golden Globe. Another 3 wins &...
# 3                 USA                           5 wins & 10 nominations.
# 4             USA, UK  Nominated for 1 Oscar. Another 1 win & 7 nomin...
# ..                ...                                                ...
# 987       Canada, USA                             5 wins & 1 nomination.
# 988               USA                                     2 nominations.
# 989  USA, New Zealand                                      1 nomination.
# 990               USA                                                NaN
# 991               USA     Won 1 Oscar. Another 46 wins & 71 nominations.
#
#      metascore  imdb_rating imdb_votes
# 0         70.0          7.3    283,945
# 1          NaN          6.2        124
# 2         49.0          5.7     97,785
# 3          NaN          5.8      7,434
# 4         35.0          4.9     33,444
# ..         ...          ...        ...
# 987        NaN          5.1      3,750
# 988        NaN          6.4      6,378
# 989        NaN          5.9      3,318
# 990        NaN          5.5      2,339
# 991       78.0          8.0    410,437
#
# [992 rows x 19 columns]

# %% [markdown]
# Checking the Info of the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdb_id      894 non-null    object
#  1   title        894 non-null    object
#  2   plot         866 non-null    object
#  3   type         894 non-null    object
#  4   rated        742 non-null    object
#  5   year         894 non-null    object
#  6   released_at  874 non-null    object
#  7   added_at     992 non-null    object
#  8   runtime      838 non-null    object
#  9   genre        885 non-null    object
#  10  director     689 non-null    object
#  11  writer       743 non-null    object
#  12  actors       870 non-null    object
#  13  language     865 non-null    object
#  14  country      869 non-null    object
#  15  awards       556 non-null    object
#  16  metascore    292 non-null    float64
#  17  imdb_rating  879 non-null    float64
#  18  imdb_votes   879 non-null    object
# dtypes: float64(2), object(17)
# memory usage: 147.4+ KB

# %% [markdown]
# Checking the Number of Numerical and Categorical Features

# %%
categorical_features = df.select_dtypes(include=['object']).columns
numerical_features = df.select_dtypes(exclude=['object']).columns

num_categorical_features = len(categorical_features)
num_numerical_features = len(numerical_features)

print("Number of categorical features:", num_categorical_features)
print("Number of numerical features:", num_numerical_features)
# Out:
# Number of categorical features: 17
# Number of numerical features: 2

# %% [markdown]
# Checking Missing Values

# %%
missing_values = df.isnull().sum()

print("Variables with missing values:")
print(missing_values[missing_values > 0])
# Out:
# Variables with missing values:
# imdb_id         98
# title           98
# plot           126
# type            98
# rated          250
# year            98
# released_at    118
# runtime        154
# genre          107
# director       303
# writer         249
# actors         122
# language       127
# country        123
# awards         436
# metascore      700
# imdb_rating    113
# imdb_votes     113
# dtype: int64

# %% [markdown]
# Resolving the Missing Values of metascore and imdb_rating (Numerical Features)

# %%
# Fill missing values in numerical variables
df['metascore'] = df['metascore'].fillna(df['metascore'].mean())
df['imdb_rating'] = df['imdb_rating'].fillna(df['imdb_rating'].median())

# %% [markdown]
# Resolving the Missing Values of Categorical Features

# %%
categorical_variables = ['title', 'plot', 'type', 'rated', 'released_at', 'genre', 'director', 'writer', 'actors', 'language', 'country', 'awards','imdb_id','year','runtime','imdb_votes']

for var in categorical_variables:
    df[var] = df[var].fillna(df[var].mode().iloc[0])

# %% [markdown]
# Checking for Missing Values after filling them

# %%
missing_values = df.isnull().sum()

print("Variables with missing values:")
print(missing_values[missing_values > 0])
# Out:
# Variables with missing values:
# Series([], dtype: int64)

# %%
display(df)
# Out:
#        imdb_id                                       title  \
# 0    tt0147800                  10 Things I Hate About You
# 1    tt7019028                        101 Dalmatian Street
# 2    tt0115433                              101 Dalmatians
# 3    tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4    tt0211181                              102 Dalmatians
# ..         ...                                         ...
# 987  tt3544734                                      Zapped
# 988  tt0186726             Zenon: Girl of the 21st Century
# 989  tt0271271                           Zenon: The Zequel
# 990  tt0379060                                   Zenon: Z3
# 991  tt2948356                                    Zootopia
#
#                                                   plot    type  rated   year  \
# 0    A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1    This series follows the lives of Delilah and D...  series      G  2018–
# 2    An evil high-fashion designer plots to steal D...   movie      G   1996
# 3    Being one of 101 takes its toll on Patch, who ...   movie      G   2002
# 4    Cruella DeVil gets out of prison and goes afte...   movie      G   2000
# ..                                                 ...     ...    ...    ...
# 987  When Zoey's mom remarries, Zoey finds it hard ...   movie   TV-G   2014
# 988  An inquisitive teenager pries into suspected d...   movie   TV-G   1999
# 989  A mischievous fifteen-year-old girl living on ...   movie   TV-G   2001
# 990  The heroine sets out to win an important compe...   movie   TV-G   2004
# 991  In a city of anthropomorphic animals, a rookie...   movie     PG   2016
#
#      released_at           added_at  runtime  \
# 0    31 Mar 1999  November 12, 2019   97 min
# 1    25 Mar 2019  February 28, 2020   30 min
# 2    27 Nov 1996  November 12, 2019  103 min
# 3    21 Jan 2003  November 12, 2019   74 min
# 4    22 Nov 2000  November 12, 2019  100 min
# ..           ...                ...      ...
# 987  23 Jun 2014  November 12, 2019  102 min
# 988  23 Jan 1999  November 12, 2019   97 min
# 989  12 Jan 2001  November 12, 2019  100 min
# 990  11 Jun 2004  November 12, 2019   81 min
# 991  04 Mar 2016  November 12, 2019  108 min
#
#                                                  genre  \
# 0                               Comedy, Drama, Romance
# 1                            Animation, Comedy, Family
# 2                     Adventure, Comedy, Crime, Family
# 3        Animation, Adventure, Comedy, Family, Musical
# 4                            Adventure, Comedy, Family
# ..                                                 ...
# 987                            Comedy, Family, Fantasy
# 988                  Adventure, Comedy, Family, Sci-Fi
# 989                  Comedy, Family, Adventure, Sci-Fi
# 990                  Adventure, Comedy, Family, Sci-Fi
# 991  Animation, Adventure, Comedy, Crime, Family, M...
#
#                                               director  \
# 0                                           Gil Junger
# 1                                          Jack Hannah
# 2                                        Stephen Herek
# 3                            Jim Kammerud, Brian Smith
# 4                                           Kevin Lima
# ..                                                 ...
# 987                                      Peter DeLuise
# 988                                    Kenneth Johnson
# 989                                         Manny Coto
# 990                                         Steve Rash
# 991  Byron Howard, Rich Moore, Jared Bush(co-director)
#
#                                                 writer  \
# 0                        Karen McCullah, Kirsten Smith
# 1               Bill Berg (story), Nick George (story)
# 2        Dodie Smith (novel), John Hughes (screenplay)
# 3    Jim Kammerud (story), Dan Root (story), Garret...
# 4    Dodie Smith (novel), Kristen Buckley (story), ...
# ..                                                 ...
# 987  Leslie Margolis (based on the novel "Boys Are ...
# 988  Marilyn Sadler (book), Roger Bollen (book), St...
# 989  Marilyn Sadler (book), Roger Bollen (book), St...
# 990  Marilyn Sadler (character from the book "Zenon...
# 991  Byron Howard (story by), Rich Moore (story by)...
#
#                                                 actors          language  \
# 0    Heath Ledger, Julia Stiles, Joseph Gordon-Levi...   English, French
# 1    Josh Brener, Michaela Dietz, Bert Davis, Abiga...           English
# 2    Glenn Close, Jeff Daniels, Joely Richardson, J...  English, Spanish
# 3    Barry Bostwick, Jason Alexander, Martin Short,...           English
# 4    Glenn Close, Gérard Depardieu, Ioan Gruffudd, ...           English
# ..                                                 ...               ...
# 987  Zendaya, Chanelle Peloso, Spencer Boldman, Emi...           English
# 988  Kirsten Storms, Raven-Symoné, Stuart Pankin, H...           English
# 989  Kirsten Storms, Shadia Simmons, Lauren Maltby,...           English
# 990  Kirsten Storms, Lauren Maltby, Alyson Morgan, ...           English
# 991  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...           English
#
#               country                                             awards  \
# 0                 USA                           2 wins & 13 nominations.
# 1     UK, USA, Canada                                      1 nomination.
# 2             USA, UK  Nominated for 1 Golden Globe. Another 3 wins &...
# 3                 USA                           5 wins & 10 nominations.
# 4             USA, UK  Nominated for 1 Oscar. Another 1 win & 7 nomin...
# ..                ...                                                ...
# 987       Canada, USA                             5 wins & 1 nomination.
# 988               USA                                     2 nominations.
# 989  USA, New Zealand                                      1 nomination.
# 990               USA                                      1 nomination.
# 991               USA     Won 1 Oscar. Another 46 wins & 71 nominations.
#
#      metascore  imdb_rating imdb_votes
# 0    70.000000          7.3    283,945
# 1    62.061644          6.2        124
# 2    49.000000          5.7     97,785
# 3    62.061644          5.8      7,434
# 4    35.000000          4.9     33,444
# ..         ...          ...        ...
# 987  62.061644          5.1      3,750
# 988  62.061644          6.4      6,378
# 989  62.061644          5.9      3,318
# 990  62.061644          5.5      2,339
# 991  78.000000          8.0    410,437
#
# [992 rows x 19 columns]

# %% [markdown]
# Checking for Duplicate Entries

# %%
# Check for duplicate entries
duplicates = df.duplicated()

# Print the duplicate entries
if duplicates.any():
    print("Duplicate entries found:")
    print(df[duplicates])
else:
    print("No duplicate entries found.")
# Out:
# Duplicate entries found:
#        imdb_id          title  \
# 64   tt0019422  Freaky Friday
# 66   tt0019422  Freaky Friday
# 73   tt0019422  Freaky Friday
# 82   tt0019422  Freaky Friday
# 88   tt0019422  Freaky Friday
# ..         ...            ...
# 935  tt0019422  Freaky Friday
# 948  tt0019422  Freaky Friday
# 965  tt0019422  Freaky Friday
# 966  tt0019422  Freaky Friday
# 980  tt0019422  Freaky Friday
#
#                                                   plot   type rated  year  \
# 64   The romantic tale of a sheltered uptown Cocker...  movie     G  2019
# 66   The romantic tale of a sheltered uptown Cocker...  movie     G  2019
# 73   The romantic tale of a sheltered uptown Cocker...  movie     G  2019
# 82   The romantic tale of a sheltered uptown Cocker...  movie     G  2019
# 88   The romantic tale of a sheltered uptown Cocker...  movie     G  2019
# ..                                                 ...    ...   ...   ...
# 935  The romantic tale of a sheltered uptown Cocker...  movie     G  2019
# 948  The romantic tale of a sheltered uptown Cocker...  movie     G  2019
# 965  The romantic tale of a sheltered uptown Cocker...  movie     G  2019
# 966  The romantic tale of a sheltered uptown Cocker...  movie     G  2019
# 980  The romantic tale of a sheltered uptown Cocker...  movie     G  2019
#
#      released_at           added_at runtime        genre     director  \
# 64   12 Nov 2019  November 12, 2019  30 min  Documentary  Jack Hannah
# 66   12 Nov 2019        May 1, 2020  30 min  Documentary  Jack Hannah
# 73   12 Nov 2019  November 12, 2019  30 min  Documentary  Jack Hannah
# 82   12 Nov 2019        May 1, 2020  30 min  Documentary  Jack Hannah
# 88   12 Nov 2019        May 1, 2020  30 min  Documentary  Jack Hannah
# ..           ...                ...     ...          ...          ...
# 935  12 Nov 2019  November 12, 2019  30 min  Documentary  Jack Hannah
# 948  12 Nov 2019        May 1, 2020  30 min  Documentary  Jack Hannah
# 965  12 Nov 2019   January 15, 2020  30 min  Documentary  Jack Hannah
# 966  12 Nov 2019  November 12, 2019  30 min  Documentary  Jack Hannah
# 980  12 Nov 2019  November 12, 2019  30 min  Documentary  Jack Hannah
#
#                                      writer          actors language country  \
# 64   Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
# 66   Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
# 73   Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
# 82   Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
# 88   Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
# ..                                      ...             ...      ...     ...
# 935  Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
# 948  Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
# 965  Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
# 966  Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
# 980  Bill Berg (story), Nick George (story)  Winston Hibler  English     USA
#
#             awards  metascore  imdb_rating imdb_votes
# 64   1 nomination.  62.061644          6.7         10
# 66   1 nomination.  62.061644          6.7         10
# 73   1 nomination.  62.061644          6.7         10
# 82   1 nomination.  62.061644          6.7         10
# 88   1 nomination.  62.061644          6.7         10
# ..             ...        ...          ...        ...
# 935  1 nomination.  62.061644          6.7         10
# 948  1 nomination.  62.061644          6.7         10
# 965  1 nomination.  62.061644          6.7         10
# 966  1 nomination.  62.061644          6.7         10
# 980  1 nomination.  62.061644          6.7         10
#
# [74 rows x 19 columns]

# %% [markdown]
# Drop the Duplicate Entries

# %%
df = df.drop_duplicates()

# %% [markdown]
# Viewing the Dataset after Dropping the Duplicates

# %%
display(df)
# Out:
#        imdb_id                                       title  \
# 0    tt0147800                  10 Things I Hate About You
# 1    tt7019028                        101 Dalmatian Street
# 2    tt0115433                              101 Dalmatians
# 3    tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4    tt0211181                              102 Dalmatians
# ..         ...                                         ...
# 987  tt3544734                                      Zapped
# 988  tt0186726             Zenon: Girl of the 21st Century
# 989  tt0271271                           Zenon: The Zequel
# 990  tt0379060                                   Zenon: Z3
# 991  tt2948356                                    Zootopia
#
#                                                   plot    type  rated   year  \
# 0    A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1    This series follows the lives of Delilah and D...  series      G  2018–
# 2    An evil high-fashion designer plots to steal D...   movie      G   1996
# 3    Being one of 101 takes its toll on Patch, who ...   movie      G   2002
# 4    Cruella DeVil gets out of prison and goes afte...   movie      G   2000
# ..                                                 ...     ...    ...    ...
# 987  When Zoey's mom remarries, Zoey finds it hard ...   movie   TV-G   2014
# 988  An inquisitive teenager pries into suspected d...   movie   TV-G   1999
# 989  A mischievous fifteen-year-old girl living on ...   movie   TV-G   2001
# 990  The heroine sets out to win an important compe...   movie   TV-G   2004
# 991  In a city of anthropomorphic animals, a rookie...   movie     PG   2016
#
#      released_at           added_at  runtime  \
# 0    31 Mar 1999  November 12, 2019   97 min
# 1    25 Mar 2019  February 28, 2020   30 min
# 2    27 Nov 1996  November 12, 2019  103 min
# 3    21 Jan 2003  November 12, 2019   74 min
# 4    22 Nov 2000  November 12, 2019  100 min
# ..           ...                ...      ...
# 987  23 Jun 2014  November 12, 2019  102 min
# 988  23 Jan 1999  November 12, 2019   97 min
# 989  12 Jan 2001  November 12, 2019  100 min
# 990  11 Jun 2004  November 12, 2019   81 min
# 991  04 Mar 2016  November 12, 2019  108 min
#
#                                                  genre  \
# 0                               Comedy, Drama, Romance
# 1                            Animation, Comedy, Family
# 2                     Adventure, Comedy, Crime, Family
# 3        Animation, Adventure, Comedy, Family, Musical
# 4                            Adventure, Comedy, Family
# ..                                                 ...
# 987                            Comedy, Family, Fantasy
# 988                  Adventure, Comedy, Family, Sci-Fi
# 989                  Comedy, Family, Adventure, Sci-Fi
# 990                  Adventure, Comedy, Family, Sci-Fi
# 991  Animation, Adventure, Comedy, Crime, Family, M...
#
#                                               director  \
# 0                                           Gil Junger
# 1                                          Jack Hannah
# 2                                        Stephen Herek
# 3                            Jim Kammerud, Brian Smith
# 4                                           Kevin Lima
# ..                                                 ...
# 987                                      Peter DeLuise
# 988                                    Kenneth Johnson
# 989                                         Manny Coto
# 990                                         Steve Rash
# 991  Byron Howard, Rich Moore, Jared Bush(co-director)
#
#                                                 writer  \
# 0                        Karen McCullah, Kirsten Smith
# 1               Bill Berg (story), Nick George (story)
# 2        Dodie Smith (novel), John Hughes (screenplay)
# 3    Jim Kammerud (story), Dan Root (story), Garret...
# 4    Dodie Smith (novel), Kristen Buckley (story), ...
# ..                                                 ...
# 987  Leslie Margolis (based on the novel "Boys Are ...
# 988  Marilyn Sadler (book), Roger Bollen (book), St...
# 989  Marilyn Sadler (book), Roger Bollen (book), St...
# 990  Marilyn Sadler (character from the book "Zenon...
# 991  Byron Howard (story by), Rich Moore (story by)...
#
#                                                 actors          language  \
# 0    Heath Ledger, Julia Stiles, Joseph Gordon-Levi...   English, French
# 1    Josh Brener, Michaela Dietz, Bert Davis, Abiga...           English
# 2    Glenn Close, Jeff Daniels, Joely Richardson, J...  English, Spanish
# 3    Barry Bostwick, Jason Alexander, Martin Short,...           English
# 4    Glenn Close, Gérard Depardieu, Ioan Gruffudd, ...           English
# ..                                                 ...               ...
# 987  Zendaya, Chanelle Peloso, Spencer Boldman, Emi...           English
# 988  Kirsten Storms, Raven-Symoné, Stuart Pankin, H...           English
# 989  Kirsten Storms, Shadia Simmons, Lauren Maltby,...           English
# 990  Kirsten Storms, Lauren Maltby, Alyson Morgan, ...           English
# 991  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...           English
#
#               country                                             awards  \
# 0                 USA                           2 wins & 13 nominations.
# 1     UK, USA, Canada                                      1 nomination.
# 2             USA, UK  Nominated for 1 Golden Globe. Another 3 wins &...
# 3                 USA                           5 wins & 10 nominations.
# 4             USA, UK  Nominated for 1 Oscar. Another 1 win & 7 nomin...
# ..                ...                                                ...
# 987       Canada, USA                             5 wins & 1 nomination.
# 988               USA                                     2 nominations.
# 989  USA, New Zealand                                      1 nomination.
# 990               USA                                      1 nomination.
# 991               USA     Won 1 Oscar. Another 46 wins & 71 nominations.
#
#      metascore  imdb_rating imdb_votes
# 0    70.000000          7.3    283,945
# 1    62.061644          6.2        124
# 2    49.000000          5.7     97,785
# 3    62.061644          5.8      7,434
# 4    35.000000          4.9     33,444
# ..         ...          ...        ...
# 987  62.061644          5.1      3,750
# 988  62.061644          6.4      6,378
# 989  62.061644          5.9      3,318
# 990  62.061644          5.5      2,339
# 991  78.000000          8.0    410,437
#
# [918 rows x 19 columns]

# %% [markdown]
# Checking for Outliers in the Data Frame

# %%
# Specify the column(s) to check for outliers
columns_to_check = ['metascore', 'imdb_rating']  # Replace with the actual column names

# Define a function to detect outliers using IQR method
def detect_outliers_iqr(data):
    # Calculate the first and third quartile
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)

    # Calculate the IQR
    IQR = Q3 - Q1

    # Define the outlier boundaries
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Find the outliers
    outliers = (data < lower_bound) | (data > upper_bound)

    return outliers

# Check for outliers in the specified columns
outliers_df = df[columns_to_check].apply(detect_outliers_iqr)

# Print the rows containing outliers
print("Rows containing outliers:")
print(df[outliers_df.any(axis=1)])
# Out:
# Rows containing outliers:
#        imdb_id                         title  \
# 0    tt0147800    10 Things I Hate About You
# 2    tt0115433                101 Dalmatians
# 4    tt0211181                102 Dalmatians
# 6    tt0046672  20,000 Leagues Under the Sea
# 7    tt0120623                  A Bug's Life
# ..         ...                           ...
# 962  tt0096438       Who Framed Roger Rabbit
# 967  tt0096446                        Willow
# 970  tt1449283               Winnie the Pooh
# 978  tt1772341                Wreck-It Ralph
# 991  tt2948356                      Zootopia
#
#                                                   plot   type  rated  year  \
# 0    A pretty, popular teenager can't go out on a d...  movie  PG-13  1999
# 2    An evil high-fashion designer plots to steal D...  movie      G  1996
# 4    Cruella DeVil gets out of prison and goes afte...  movie      G  2000
# 6    A ship sent to investigate a wave of mysteriou...  movie      G  1954
# 7    A misfit ant, looking for "warriors" to save h...  movie      G  1998
# ..                                                 ...    ...    ...   ...
# 962  A toon-hating detective is a cartoon rabbit's ...  movie     PG  1988
# 967  A young farmer is chosen to undertake a perilo...  movie     PG  1988
# 970  While searching for honey, Pooh and his friend...  movie      G  2011
# 978  A video game villain wants to be a hero and se...  movie     PG  2012
# 991  In a city of anthropomorphic animals, a rookie...  movie     PG  2016
#
#      released_at           added_at  runtime  \
# 0    31 Mar 1999  November 12, 2019   97 min
# 2    27 Nov 1996  November 12, 2019  103 min
# 4    22 Nov 2000  November 12, 2019  100 min
# 6    20 Jul 1955  November 12, 2019  127 min
# 7    25 Nov 1998  November 12, 2019   95 min
# ..           ...                ...      ...
# 962  22 Jun 1988  November 12, 2019  104 min
# 967  20 May 1988  November 12, 2019  126 min
# 970  15 Jul 2011  November 12, 2019   63 min
# 978  02 Nov 2012  November 12, 2019  101 min
# 991  04 Mar 2016  November 12, 2019  108 min
#
#                                                  genre  \
# 0                               Comedy, Drama, Romance
# 2                     Adventure, Comedy, Crime, Family
# 4                            Adventure, Comedy, Family
# 6            Adventure, Drama, Family, Fantasy, Sci-Fi
# 7                 Animation, Adventure, Comedy, Family
# ..                                                 ...
# 962  Animation, Adventure, Comedy, Crime, Family, F...
# 967         Action, Adventure, Drama, Fantasy, Romance
# 970      Animation, Adventure, Comedy, Family, Musical
# 978      Animation, Adventure, Comedy, Family, Fantasy
# 991  Animation, Adventure, Comedy, Crime, Family, M...
#
#                                               director  \
# 0                                           Gil Junger
# 2                                        Stephen Herek
# 4                                           Kevin Lima
# 6                                    Richard Fleischer
# 7           John Lasseter, Andrew Stanton(co-director)
# ..                                                 ...
# 962                  Robert Zemeckis, Richard Williams
# 967                                         Ron Howard
# 970                      Stephen J. Anderson, Don Hall
# 978                                         Rich Moore
# 991  Byron Howard, Rich Moore, Jared Bush(co-director)
#
#                                                 writer  \
# 0                        Karen McCullah, Kirsten Smith
# 2        Dodie Smith (novel), John Hughes (screenplay)
# 4    Dodie Smith (novel), Kristen Buckley (story), ...
# 6                             Earl Felton (screenplay)
# 7    John Lasseter (original story by), Andrew Stan...
# ..                                                 ...
# 962  Gary K. Wolf (novel), Jeffrey Price (screenpla...
# 967  George Lucas (story by), Bob Dolman (screenpla...
# 970  Stephen J. Anderson (story by), Clio Chiang (s...
# 978  Rich Moore (story by), Phil Johnston (story by...
# 991  Byron Howard (story by), Rich Moore (story by)...
#
#                                                 actors          language  \
# 0    Heath Ledger, Julia Stiles, Joseph Gordon-Levi...   English, French
# 2    Glenn Close, Jeff Daniels, Joely Richardson, J...  English, Spanish
# 4    Glenn Close, Gérard Depardieu, Ioan Gruffudd, ...           English
# 6    Kirk Douglas, James Mason, Paul Lukas, Peter L...           English
# 7    Dave Foley, Kevin Spacey, Julia Louis-Dreyfus,...           English
# ..                                                 ...               ...
# 962  Bob Hoskins, Christopher Lloyd, Joanna Cassidy...           English
# 967  Val Kilmer, Joanne Whalley, Warwick Davis, Jea...           English
# 970  John Cleese, Jim Cummings, Bud Luckey, Craig F...           English
# 978  John C. Reilly, Sarah Silverman, Jack McBrayer...           English
# 991  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...           English
#
#      country                                             awards  metascore  \
# 0        USA                           2 wins & 13 nominations.       70.0
# 2    USA, UK  Nominated for 1 Golden Globe. Another 3 wins &...       49.0
# 4    USA, UK  Nominated for 1 Oscar. Another 1 win & 7 nomin...       35.0
# 6        USA      Won 2 Oscars. Another 3 wins & 3 nominations.       83.0
# 7        USA  Nominated for 1 Oscar. Another 14 wins & 20 no...       77.0
# ..       ...                                                ...        ...
# 962      USA    Won 3 Oscars. Another 21 wins & 21 nominations.       83.0
# 967      USA  Nominated for 2 Oscars. Another 1 win & 9 nomi...       47.0
# 970      USA                           2 wins & 25 nominations.       74.0
# 978      USA  Nominated for 1 Oscar. Another 33 wins & 41 no...       72.0
# 991      USA     Won 1 Oscar. Another 46 wins & 71 nominations.       78.0
#
#      imdb_rating imdb_votes
# 0            7.3    283,945
# 2            5.7     97,785
# 4            4.9     33,444
# 6            7.2     27,761
# 7            7.2    257,065
# ..           ...        ...
# 962          7.7    175,505
# 967          7.3     97,309
# 970          7.2     20,673
# 978          7.7    365,043
# 991          8.0    410,437
#
# [303 rows x 19 columns]

# %% [markdown]
# Ploting the Outliers of IMDB Rating

# %%
outliers_imdb_rating = df[outliers_df['imdb_rating']]['imdb_rating']

plt.figure(figsize=(8, 6))
plt.scatter(range(len(outliers_imdb_rating)), outliers_imdb_rating, color='red', label='Outliers')
plt.xlabel('Data Points')
plt.ylabel('IMDb Rating')
plt.title('Outliers of IMDB Rating')
plt.legend()
plt.show()

# %% [markdown]
# Ploting the Outliers of Meta Score

# %%
outliers_metascore = df[outliers_df['metascore']]['metascore']

plt.figure(figsize=(8, 6))
plt.scatter(range(len(outliers_metascore)), outliers_metascore, color='red', label='Outliers')
plt.xlabel('Data Points')
plt.ylabel('Metascore')
plt.title('Outliers of Metascore')
plt.legend()
plt.show()

# %% [markdown]
# Applying Log Transformation to Handle the Outliers

# %%
#df_transformed = df
#df_transformed['metascore'] = np.log(df['metascore'])
#df_transformed['imdb_rating'] = np.log(df['imdb_rating'])
from scipy.stats.mstats import winsorize

# Apply winsorization to selected columns
df_winsorized = df.copy()
df_winsorized['metascore'] = winsorize(df['metascore'], limits=[0.05, 0.05])
df_winsorized['imdb_rating'] = winsorize(df['imdb_rating'], limits=[0.05, 0.05])

# %% [markdown]
# Saving the Data Frame after cleaning

# %%
df.to_csv('cleaned_dataset_disney.csv', index=False)

# %% [markdown]
# Looking for the Descriptive Statistics

# %%
descriptive_stats = df.describe()

print(descriptive_stats)
# Out:
#         metascore  imdb_rating
# count  918.000000   918.000000
# mean    62.061644     6.658279
# std      8.887329     0.998457
# min     19.000000     1.500000
# 25%     62.061644     6.100000
# 50%     62.061644     6.700000
# 75%     62.061644     7.300000
# max     99.000000     9.700000

# %% [markdown]
# The Co-relation Heat Map

# %%
import seaborn as sns



correlation_matrix = df.corr()

# Create a correlation heatmap
sns.heatmap(correlation_matrix, annot=True)

# Set the title of the heatmap
plt.title('Correlation Heatmap')

# Display the heatmap
plt.show()
# Out:
# <ipython-input-608-04f756ca9f14>:5: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# Distribution of IMDB Rating

# %%
fig = px.histogram(df['imdb_rating'],nbins=40,labels={'value':'imdb_rating'})
fig.update_layout(title='Distribution of the IMDB Ratings',title_x=0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="050b0f03-db3b-4dbb-a441-a8adc2f54024" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("050b0f03-db3b-4dbb-a441-a8adc2f54024")) {                    Plotly.newPlot(                        "050b0f03-db3b-4dbb-a441-a8adc2f54024",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=imdb_rating<br>imdb_rating=%{x}<br>count=%{y}<extra></extra>","legendgroup":"imdb_rating","marker":{"color":"#636efa","pattern":{"shape":""}},"name":
.1,6.7,6.7,7.3,6.2,6.8,8.2,7.3,5.3,6.1,6.6,6.9,6.9,6.7,7.2,7.2,7.4,5.0,7.1,6.9,4.7,9.1,8.6,6.7,7.1,8.0,7.0,7.6,5.4,4.2,6.0,6.2,6.9,6.6,6.5,8.5,7.6,5.6,6.3,7.5,5.5,6.5,7.2,6.5,8.7,7.6,5.9,6.7,7.7,7.6,7.1,7.4,7.6,7.5,6.6,7.9,7.1,7.2,6.1,7.1,6.5,6.7,8.1,4.7,6.2,7.1,7.1,8.1,6.3,5.8,6.4,5.4,6.9,5.8,6.9,6.9,6.5,6.9,5.0,6.5,5.6,4.7,6.7,5 ...

# %% [markdown]
# Top 5 Shows with the Highest IMDB Rating

# %%
df_top10 = df.sort_values('imdb_rating',ascending=False).head(5)
fig = go.Figure(data=[go.Bar(
            x=df_top10['title'], y=df_top10['imdb_rating'],
            text=df_top10['imdb_rating'],
            textposition='auto',
        )])
fig.update_layout(title='Top 5 Shows with the Highest IMDB Ratings',title_x=0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fed45a88-733d-4840-9627-9b8cb061638b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fed45a88-733d-4840-9627-9b8cb061638b")) {                    Plotly.newPlot(                        "fed45a88-733d-4840-9627-9b8cb061638b",                        [{"text":[9.7,9.1,8.9,8.9,8.8],"textposition":"auto","x":["Bluey","The Imagineering Story","Gravity Falls","Dr. T, Lone Star Vet","Muppet Moments"],"y":[9.7,9.1,8.9,8.9,8.8],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}] ...

# %% [markdown]
# Top 5 Movies with the Highest IMDB Ratings

# %%
top10_m = df[df['type'] == 'movie'].sort_values('imdb_rating',ascending=False).head(5)

fig = px.bar(top10_m,top10_m['title'],top10_m['imdb_rating'],text=top10_m['imdb_rating'])
fig.update_layout(title='Top 5 Movies with highest IMDB Rating',title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="31febe8d-48bf-48df-a36d-06a2382d6ecd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31febe8d-48bf-48df-a36d-06a2382d6ecd")) {                    Plotly.newPlot(                        "31febe8d-48bf-48df-a36d-06a2382d6ecd",                        [{"alignmentgroup":"True","hovertemplate":"title=%{x}<br>imdb_rating=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[8.7,8.6,8.5,8.5,8.4],"textposition":"auto","x":["Star Wars: Episode V - The Empire Strikes Back","Star Wars: Episode IV - A New Hope","The Lion King","Disney's Newsies: The Broadway Musical!","Presto"],"xaxis":"x","y":[8.7,8.6,8.5,8.5,8.4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"soli ...

# %% [markdown]
# Top 5 Series with the Highest IMDB Ratings

# %%
top10_m = df[df['type'] == 'series'].sort_values('imdb_rating',ascending=False).head(5)

fig = px.bar(top10_m,top10_m['title'],top10_m['imdb_rating'],text=top10_m['imdb_rating'])
fig.update_layout(title='Top 5 Series with highest IMDB Rating',title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2cb0ca83-daac-4633-8752-21049b7f439d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cb0ca83-daac-4633-8752-21049b7f439d")) {                    Plotly.newPlot(                        "2cb0ca83-daac-4633-8752-21049b7f439d",                        [{"alignmentgroup":"True","hovertemplate":"title=%{x}<br>imdb_rating=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[9.7,9.1,8.9,8.9,8.8],"textposition":"auto","x":["Bluey","The Imagineering Story","Gravity Falls","Dr. T, Lone Star Vet","Muppet Moments"],"xaxis":"x","y":[9.7,9.1,8.9,8.9,8.8],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","m ...

#
6,476","1,288","35,066","8,392","38,414","10","2,324","823","24,212","312","4,958","6,553","7,035","43,653","195,894","77,328","52,782","55,628","2,038","10","14","89,713","74,143","101,062","19,123","13,127","40,421","39,775","137,074","12,439","1,485","382","894","34","2,484","367","462","826","386","2,473","8,812","421,204","2,814","23,891","682","17","10","577,209","43,808","5,423","94","183","63,682","2,240","2,638","2,671","7,095","10","54,474","13,829","57,814","3,897","10","11,715","10","248,903","1,922","4,615","17,198","10","15,008","6,574","1,603","22,111","205","125","22,405","4,372","2,030","3,728","77","56","3,834","10,599","12,217","4,349","12,134","116,990","9,837","1,848","980","401","127","617","17","680","54","65","161","364","13,515","803","4,565","2,731","221","1,429","1,205","5,221","727","17,178","160,264","7,344","11,210","16,649","1,838","362","63","56","5,581","6,337","686" ...

# %% [markdown]
# Top 5 shows/movies/episodes with the most IMDB Votes

# %%
df_top5_v = df.sort_values('imdb_votes',ascending=False).head(5)
df_top5_v['imdb_votes'] = df_top5_v['imdb_votes'].apply(lambda x: x.replace(',','.')).astype(float)

fig = go.Figure(data=[go.Bar(
            x=df_top5_v['title'], y=df_top5_v['imdb_votes'],
            text=df_top5_v['imdb_votes'],
            textposition='auto',
        )])

fig.update_layout(title='Top 5 shows/movies/episodes with the most IMDB Votes',title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d8df55d4-b351-45ab-9213-ec14a0fcc263" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8df55d4-b351-45ab-9213-ec14a0fcc263")) {                    Plotly.newPlot(                        "d8df55d4-b351-45ab-9213-ec14a0fcc263",                        [{"text":[999.0,998.0,993.0,992.127,991.0],"textposition":"auto","x":["The Incredible Dr. Pol","Elena of Avalor","Boat Builders","Pirates of the Caribbean: The Curse of the Black Pearl","Elmer Elephant"],"y":[999.0,998.0,993.0,992.127,991.0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{ ...

# %% [markdown]
# Top 5 Genres based on the IMDB Ratings

# %%
fig = go.Figure(data=[go.Bar(
            x=df_top5_v['genre'], y=df_top5_v['imdb_votes'],
            text=round(df_top5_v['imdb_votes'],0),
            textposition='auto',
        )])

fig.update_layout(title='Top 5 Genres with the most IMDB Votes',title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="73cfec12-34a8-44e7-8cfb-1a6a49f60035" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73cfec12-34a8-44e7-8cfb-1a6a49f60035")) {                    Plotly.newPlot(                        "73cfec12-34a8-44e7-8cfb-1a6a49f60035",                        [{"text":[999.0,998.0,993.0,992.0,991.0],"textposition":"auto","x":["Documentary, Reality-TV","Animation, Action, Adventure, Family, Fantasy, Musical","Animation, Comedy, Family, Short","Action, Adventure, Fantasy","Family, Animation, Short, Comedy"],"y":[999.0,998.0,993.0,992.127,991.0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ti ...

# %% [markdown]
# WordCloud of the most frequent words in the Titles of the Dataset

# %%
stopwords = list(STOPWORDS)

genre = wordcloud.WordCloud(max_words=6000,stopwords=stopwords,background_color='white')

genre.generate(str(df['plot']))

plt.figure(figsize=(15,15))
plt.imshow(genre,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Top 5 Writer

# %%
df_writer = df.assign(var1 = df.writer.str.split(',')).explode('var1').reset_index(drop = True)

df_writer['splitted'] = df_writer.var1.str.lstrip()
writers = pd.DataFrame(df_writer['splitted'].value_counts()).reset_index().head(5)

fig = px.bar(writers,writers['index'],writers['splitted'],labels={'index':'name','splitted':'count'})
fig.update_layout(title='Top 5 Writers',title_x=0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="
0,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,95.0,62.06164383561644,62.06164383561644,54.0,59.0,33.0,62.06164383561644,63.0,53.0,62.06164383561644,53.0,62.06164383561644,62.06164383561644,74.0,62.06164383561644,62.06164383561644,71.0,42.0,62.06164383561644,62.06164383561644,67.0,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,69.0,62.06164383561644,62.06164383561644,62.06164383561644,48.0,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,68.0,62.06164383561644,73.0,57.0,59.0,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,46.0,62.06164383561644,62.06164383561644,48.0,62.06164383561644,62.06164383561644,85.0,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,81.0,62.06164383561644,36.0,33.0,62.06164383561644,60.0,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,71.0,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,56.0,56.0,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,45.0,62.06164383561644,62.06164383561644,61.0,68.0,57.0,57.0,62.06164383561644,72.0,69.0,62.06164383561644,62.06164383561644,62.06164383561644,46.0,49.0,62.06164383561644,62.06164383561644,79.0,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644,62.06164383561644, ...

# %% [markdown]
# Top 5 Languages

# %%
df_lang = df.assign(var1 = df.language.str.split(',')).explode('var1').reset_index(drop = True)

df_lang['splitted'] = df_lang.var1.str.lstrip()

lang = pd.DataFrame(df_lang['splitted'].value_counts()).reset_index().head(10)
lang.drop(df.index[5], inplace=True)

fig = px.bar(lang,lang['index'],lang['splitted'])
fig.update_layout(title='Top 10 Languages',title_x=0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d5ffdb85-3f03-49c8-98f8-a2bbaadfcca4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5ffdb85-3f03-49c8-98f8-a2bbaadfcca4")) {                    Plotly.newPlot(                        "d5ffdb85-3f03-49c8-98f8-a2bbaadfcca4",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>splitted=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["English","French","Spanish","German","Italian","Mandarin","Japanese","Portuguese","Russian"],"xaxis":"x","y":[904,34,31,18,11,9,9,7,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlin ...

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(df, vars=['metascore', 'imdb_rating'])
plt.show()

# %% [markdown]
# Number of Metascore Rating by Genre

# %%
fig = px.pie(df['metascore'],values=df['metascore'],names=df['genre'])
fig.update_traces(textposition='inside')
fig.update_layout(title='Number of Metascore Ratings by Genre',title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d257be3a-779c-44d4-b556-f8e4f4da59ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d257be3a-779c-44d4-b556-f8e4f4da59ef")) {                    Plotly.newPlot(                        "d257be3a-779c-44d4-b556-f8e4f4da59ef",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Comedy, Drama, Romance","Animation, Comedy, Family","Adventure, Comedy, Crime, Family","Animation, Adventure, Comedy, Family, Musical","Adventure, Comedy, Family","Comedy, Fantasy, Romance","Adventure, Drama, Family, Fantasy, Sci-Fi","Animation, Adventure, Comedy, Family","Music","Animation, Adventure, Comedy, Family, Musical, Romance","Adventure, Comedy, Family, Fantasy, Romance","Animation, Short, Comedy","Drama, Family, Romance","Adventure, Family","Adventure, Family, Fantasy, Sci-Fi","Adventure, Family, Fantasy, Musical, Romance","Animation, Adventure, Comedy, Family, Fantasy, Musical, Romance","Animation, Adventure, Comedy, Family, Fantasy, Musical, Romance","Animation, Adventure, Comedy, Family, Fantasy, Musical, Romance","Animation, Adventure, Family, Fantasy, Musical","Adventure, Family, Fantasy","Documentary, Family","Family, Comedy, Animation, Short","Drama, Family, Sport","Comedy, Family, Music","Comedy, Family, Reality-TV","Documentary","Documentary","Family, Drama","Animation, Comedy, Family, Sport","Comedy, Family","Family, Comedy, Musical","History","Documentary","Action, Adventure, Comedy, Family, Western","Documentary, Adventure, Mystery","Animation, Action, Adventure, Comedy, Drama, Family, Fantasy, Sci-Fi","Animation, Action, Adventure, Family, Fantasy, Sci-Fi","Animation, Short, Action, Adventure, Comedy, Family","Comedy, Family, Music","Action, Adventure, Fantasy, Sci-Fi","Documentary","Family, Animation, Short, Comedy","Comedy, Family, Fantasy, Musical, Romance","Animation, Drama, Family","Animation, Adventure, Drama, Family, Romance","Animation, Short, Family, Fantasy","Documentary","Animation, Family, Comedy, Short","Animation, Short, Comedy","Animation, Family, Fantasy, Musical, Romance","Animation, Comedy, Family, Fantasy, Musical, Romance","Animation, Family, Fantasy, Music, Musical","Comedy, Drama, Family","Animation, Adventure, Comedy, Family, Fantasy, Musical","Comedy, Family, Fantasy, Romance","Animation, Comedy, Family","Documentary","Adventure, Family","Comedy, Family, Sci-Fi","Comedy","Animation, Short, Adventure, Comedy, Family","Documentary","Animation, Action, Adventure, Family, Sci-Fi","Animation, Comedy, Family","Documentary","Comedy, Family, Fantasy","Comedy, Crime, Family","Animation","Animation, Comedy, Family, Short","Animation, Adventure, Comedy, Drama, Family","Animation, Action, Adventure, Comedy, Crime, Family","Documentary","Animation, Short, Comedy, Family, Musical","Comedy, Drama, Family","Documentary, Comedy, Drama, Game-Show, Reality-TV","Animation, Adventure, Comedy, Family, Fantasy","Animation, Adventure, Family, Fantasy","Documentary","Drama, Family, Sport","Animation, Adventure, Comedy, Family, Fantasy","Animation, Adventure, Comedy, Family, Fantasy","Family","Reality-TV","Animation, Short, Adventure, Comedy, Family, Sci-Fi","Comedy, Drama, Family","Adventure, Comedy, Family","Comedy, Family, Music, Musical, Romance","Comedy, Family, Music, Musical, Romance","Comedy, Family, Sci-Fi","Adventure, Comedy, Drama, Family","Animation, Short, Comedy","Animation, Comedy, Family, Sport","Animation, Adventure, Comedy, Family, Sport","Animation, Adventure, Comedy, Family, Sport","Animation, Adventure, Comedy, Family","Animation, Adventure, Comedy","Animation, Adventure, Comedy","Animation, Comedy, Family","Animation, Adventure, Co ...

# %% [markdown]
# Sum of IMDB Ratings per show types

# %%
fig = px.pie(df,names=df['type'],values=df['imdb_rating'],labels=df['type'],hole=0.5)
fig.update_layout(title='Sum of IMDB Ratings per show types',title_x=0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="11b3c926-a947-4094-9a63-4d9a9361bae4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11b3c926-a947-4094-9a63-4d9a9361bae4")) {                    Plotly.newPlot(                        "11b3c926-a947-4094-9a63-4d9a9361bae4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"type=%{label}<br>imdb_rating=%{value}<extra></extra>","labels":["movie","series","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","series","movie","series","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","series","movie","series","movie","movie","series","movie","movie","movie","series","movie","movie","series","movie","movie","series","series","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","episode","episode","episode","episode","episode","movie","episode","episode","episode","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","series","movie","series","movie","movie","series","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","series","movie","movie","series","series","movie","movie","series","series","series","series","series","movie","movie","series","series","series","series","series","series","series","series","series","movie","series","series","series","episode","movie","series","series","series","series","series","series","series","movie","series","movie","series","series","series","episode","series","series","series","series","series","series","movie","series","episode","movie","movie","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","series","series","movie","movie","movie","movie","movie","movie","movie","movie","movie","series","series","movie","movie","movie","movie","movie","series","movie","movie","series","movie","movie","movie","movie","episode","movie","movie","series","movie","movie","movie","movie","series","movie","series","movie","movie","series","movie","movie","series","series","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","movie","movie","episode","movie","episode","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","series","movie","series","series","movie","movie","series","movie","movie","movie","movie","movie","movie","series","series","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","movie","series","movie","episode","movie","movie","movie","movie","movie","movie","movie","series","series","movie","movie","movie","movie","movie","movie","movie","series","episode","movie","movie","movie","movie","series","movie","movie","movie","movie","movie","movie","movie","series","movie","movie","movie","series","movie","movie","movie","series","movie","movie","movie","movie","movie","series","series","series","series","series" ...

# %% [markdown]
# Sum of IMDB Ratings grouped by Age Ratings

# %%
fig = px.treemap(df, path=['rated'], values=df['imdb_rating'], height=700,
                 title='Sum of IMDB Ratings grouped by Age Ratings', color_discrete_sequence = px.colors.qualitative.Dark2)
fig.data[0].textinfo = 'label+text+value'
fig.update_layout(title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5223b39d-c125-4868-878a-fb89a433af00" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5223b39d-c125-4868-878a-fb89a433af00")) {                    Plotly.newPlot(                        "5223b39d-c125-4868-878a-fb89a433af00",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>imdb_rating=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["APPROVED","Approved","G","NOT RATED","Not Rated","PASSED","PG","PG-13","Passed","TV-14","TV-G","TV-PG","TV-Y","TV-Y7","TV-Y7-FV","UNRATED","Unrated"],"labels":["APPROVED","Approved","G","NOT RATED","Not Rated","PASSED","PG","PG-13","Passed","TV-14","TV-G","TV-PG","TV-Y","TV-Y7","TV-Y7-FV","UNRATED","Unrated"],"name":"","parents":["","","","","","","","","","","","","","","","",""],"values":[57.2,368.4,2567.9,6.3,106.6,14.9,1002.8,269.3,29.9,26.1,817.2,274.7,228.1,288.4,20.2,20.3,14.0],"type":"treemap","textinfo":"label+text+value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","ma ...

# %% [markdown]
# **Content Based Recommender System Based on Movie Different Metrics**

# %%
df1 =  pd.read_csv("/content/cleaned_dataset_disney.csv")
features=['genre','actors','plot','title']
filters = df1[features]

# %%
print(filters)
# Out:
#                                                  genre  \
# 0                               Comedy, Drama, Romance
# 1                            Animation, Comedy, Family
# 2                     Adventure, Comedy, Crime, Family
# 3        Animation, Adventure, Comedy, Family, Musical
# 4                            Adventure, Comedy, Family
# ..                                                 ...
# 913                            Comedy, Family, Fantasy
# 914                  Adventure, Comedy, Family, Sci-Fi
# 915                  Comedy, Family, Adventure, Sci-Fi
# 916                  Adventure, Comedy, Family, Sci-Fi
# 917  Animation, Adventure, Comedy, Crime, Family, M...
#
#                                                 actors  \
# 0    Heath Ledger, Julia Stiles, Joseph Gordon-Levi...
# 1    Josh Brener, Michaela Dietz, Bert Davis, Abiga...
# 2    Glenn Close, Jeff Daniels, Joely Richardson, J...
# 3    Barry Bostwick, Jason Alexander, Martin Short,...
# 4    Glenn Close, Gérard Depardieu, Ioan Gruffudd, ...
# ..                                                 ...
# 913  Zendaya, Chanelle Peloso, Spencer Boldman, Emi...
# 914  Kirsten Storms, Raven-Symoné, Stuart Pankin, H...
# 915  Kirsten Storms, Shadia Simmons, Lauren Maltby,...
# 916  Kirsten Storms, Lauren Maltby, Alyson Morgan, ...
# 917  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...
#
#                                                   plot  \
# 0    A pretty, popular teenager can't go out on a d...
# 1    This series follows the lives of Delilah and D...
# 2    An evil high-fashion designer plots to steal D...
# 3    Being one of 101 takes its toll on Patch, who ...
# 4    Cruella DeVil gets out of prison and goes afte...
# ..                                                 ...
# 913  When Zoey's mom remarries, Zoey finds it hard ...
# 914  An inquisitive teenager pries into suspected d...
# 915  A mischievous fifteen-year-old girl living on ...
# 916  The heroine sets out to win an important compe...
# 917  In a city of anthropomorphic animals, a rookie...
#
#                                           title
# 0                    10 Things I Hate About You
# 1                          101 Dalmatian Street
# 2                                101 Dalmatians
# 3    101 Dalmatians 2: Patch's London Adventure
# 4                                102 Dalmatians
# ..                                          ...
# 913                                      Zapped
# 914             Zenon: Girl of the 21st Century
# 915                           Zenon: The Zequel
# 916                                   Zenon: Z3
# 917                                    Zootopia
#
# [918 rows x 4 columns]

# %%
#Cleaning the Data by Making all the Words in Lower Case.
def clean_data(x):
        return str.lower(x.replace(" ", ""))

# %%
for feature in features:
    filters[feature] = filters[feature].apply(clean_data)
    
filters.head()
# Out:
# <ipython-input-633-5b22918e8429>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                        genre  \
# 0                       comedy,drama,romance
# 1                    animation,comedy,family
# 2              adventure,comedy,crime,family
# 3  animation,adventure,comedy,family,musical
# 4                    adventure,comedy,family
#
#                                               actors  \
# 0  heathledger,juliastiles,josephgordon-levitt,la...
# 1  joshbrener,michaeladietz,bertdavis,abigailzoel...
# 2  glennclose,jeffdaniels,joelyrichardson,joanplo...
# 3  barrybostwick,jasonalexander,martinshort,bobby...
# 4  glennclose,gérarddepardieu,ioangruffudd,alicee...
#
#                                                 plot  \
# 0  apretty,popularteenagercan'tgooutonadateuntilh...
# 1  thisseriesfollowsthelivesofdelilahanddoug,desc...
# 2  anevilhigh-fashiondesignerplotstostealdalmatia...
# 3  beingoneof101takesitstollonpatch,whodoesn'tfee...
# 4  cruelladevilgetsoutofprisonandgoesafterthepupp...
#
#                                    title
# 0                  10thingsihateaboutyou
# 1                     101dalmatianstreet
# 2                          101dalmatians
# 3  101dalmatians2:patch'slondonadventure
# 4                          102dalmatians

# %%
# Creating our "metadata soup", which is a string that contains all the metadata that we want to feed to our vectorizer.
def create_soup(x):
    return x['actors'] + ' ' +x['genre']+' '+ x['plot']

# %%
filters['soup'] = filters.apply(create_soup, axis=1)
# Out:
# <ipython-input-635-4ea85fff18a9>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(filters['soup'])

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
filters.sort_values(by='genre').head(10)
# Out:
#                                                  genre  \
# 192            action,adventure,biography,drama,family
# 381                            action,adventure,comedy
# 125               action,adventure,comedy,crime,family
# 314  action,adventure,comedy,crime,family,romance,s...
# 351        action,adventure,comedy,crime,family,sci-fi
# 546       action,adventure,comedy,drama,family,fantasy
# 534           action,adventure,comedy,drama,family,war
# 818                     action,adventure,comedy,family
# 154      action,adventure,comedy,family,fantasy,sci-fi
# 279      action,adventure,comedy,family,fantasy,sci-fi
#
#                                                 actors  \
# 192     pintocolvig,waltdisney,chethuntley,dickvandyke
# 381  sadiestanley,seangiambrone,ciararileywilson,to...
# 125  emilyosment,davidhenrie,jasonearles,jonathankeltz
# 314      deanjones,donknotts,juliesommars,jacquesmarin
# 351  matthewbroderick,ruperteverett,joelyfisher,mic...
# 546  brycedallashoward,robertredford,oakesfegley,oo...
# 534        dannyglover,rayliotta,denisleary,douge.doug
# 818      dylansprouse,colesprouse,brendasong,debbyryan
# 154  oliviaholt,kerrisdorsey,brendanmeyer,katherine...
# 279  billnighy,willarnett,zachgalifianakis,kelligarner
#
#                                                   plot  \
# 192  walttakesviewersonyetanothertourofdisneylandto...
# 381  heroeskimandronfacetheproblemsofstartinghighsc...
# 125  melissahasabadcaseofsiblingrivalry,onlyhercomp...
# 314  herbie,thevolkswagenbeetlewithamindofitsown,is...
# 351  asecurityguard'sdreamscometruewhenheisselected...
# 546  theadventuresofanorphanedboynamedpeteandhisbes...
# 534  tokeeptheloyaltyofavillageduringthevietnamwar,...
# 818  spin-offofthehitdisneychannelseries"thesuiteli...
# 154  ateengirlgoesonamissiontorecaptureadangerousmo...
# 279  aspeciallytrainedsquadofguineapigsisdispatched...
#
#                           title  \
# 192  disneylandaroundtheseasons
# 381                 kimpossible
# 125                   dadnapped
# 314      herbiegoestomontecarlo
# 351             inspectorgadget
# 546                pete'sdragon
# 534          operationdumbodrop
# 818          thesuitelifeondeck
# 154              girlvs.monster
# 279                     g-force
#
#                                                   soup
# 192  pintocolvig,waltdisney,chethuntley,dickvandyke...
# 381  sadiestanley,seangiambrone,ciararileywilson,to...
# 125  emilyosment,davidhenrie,jasonearles,jonathanke...
# 314  deanjones,donknotts,juliesommars,jacquesmarin ...
# 351  matthewbroderick,ruperteverett,joelyfisher,mic...
# 546  brycedallashoward,robertredford,oakesfegley,oo...
# 534  dannyglover,rayliotta,denisleary,douge.doug ac...
# 818  dylansprouse,colesprouse,brendasong,debbyryan ...
# 154  oliviaholt,kerrisdorsey,brendanmeyer,katherine...
# 279  billnighy,willarnett,zachgalifianakis,kelligar...

# %%
# Reset index of our main Dataframe and construct reverse mapping as before
filters=filters.reset_index()
indices = pd.Series(filters.index, index=filters['title'])

# %%
def get_recommendations_new(title, cosine_sim):
    title=title.replace(' ','').lower()
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df['title'].iloc[movie_indices]

# %% [markdown]
# **Testing the Recommendation System**

# %%
get_recommendations_new('Coco', cosine_sim2)
# Out:
# 267                                  Fantasia
# 664                            Saludos Amigos
# 709                          Star Wars Rebels
# 195                            The Lion Guard
# 962                   Who Framed Roger Rabbit
# 80     The Brave Little Toaster to the Rescue
# 917    Tinker Bell and the Great Fairy Rescue
# 918         Tinker Bell and the Lost Treasure
# 737                                  TaleSpin
# 862                   The Rescuers Down Under
# Name: title, dtype: object

# %% [markdown]
# **Evaluation**

# %% [markdown]
# For content-based Recommender it is difficult to measure accuracy, and precision because here user rating is not available in our dataset.
#
# Content-Based Filtering: Content-based filtering is used to recommend movies based on their metadata such as genre, actors, and plot. The code constructs a "metadata soup" by combining the relevant metadata features for each movie. It then applies a CountVectorizer to convert the text data into a numerical representation. Cosine similarity is computed on the count matrix to measure the similarity between movies based on their metadata.
#
# Cosine Similarity: Cosine similarity is a metric used to determine the similarity between two vectors. In the code, cosine_similarity from sklearn.metrics.pairwise is used to calculate the cosine similarity matrix. It measures the similarity between each pair of movies based on their metadata representations (count matrix).

# %% [markdown]
# ## Using ML Algorithms

# %% [markdown]
# Decision Tree

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.preprocessing import LabelEncoder
import graphviz

# Load the dataset
df = pd.read_csv("/content/cleaned_dataset_disney.csv")

# Select relevant features for recommendation
features = ['plot', 'genre', 'actors', 'director']

# Drop rows with missing values in selected features
df = df.dropna(subset=features)

# Combine the features into a single column
df['combined_features'] = df[features].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Create the count matrix
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df['combined_features'])

# Apply label encoding to convert genre labels to numerical values
label_encoder = LabelEncoder()
df['genre_encoded'] = label_encoder.fit_transform(df['genre'])

# Create the decision tree classifier
decision_tree = DecisionTreeClassifier()

# Train the decision tree model
decision_tree.fit(count_matrix, df['genre_encoded'])

# Visualize the decision tree
dot_data = export_graphviz(decision_tree, out_file=None, feature_names=count.get_feature_names_out(), class_names=label_encoder.classes_, filled=True, rounded=True, special_characters=True)
graph = graphviz.Source(dot_data)
graph.format = 'png'
graph.render("decision_tree", format="png", view=True, cleanup=True, quiet=False, quiet_view=False)

# Function to recommend movies using the decision tree model
def recommend_movies(title, decision_tree, count_vectorizer, label_encoder, top_n=10):
    # Transform the input title into a count matrix
    title_count = count_vectorizer.transform([title])

    # Predict the genre of the input title using the decision tree model
    predicted_genre = decision_tree.predict(title_count)[0]

    # Get the indices of movies with the predicted genre
    genre_indices = df[df['genre_encoded'] == predicted_genre].index

    # Exclude the input title from the recommended movies
    genre_indices = genre_indices[genre_indices != title_idx]

    # Calculate the similarity scores between the input title and recommended movies
    similarity_scores = cosine_similarity(title_count, count_matrix[genre_indices])

    # Sort the movies based on similarity scores
    sorted_indices = similarity_scores.argsort()[0][::-1]

    # Get the top N most similar movies
    top_movies = df.iloc[genre_indices[sorted_indices[:top_n]]]['title']

    return top_movies

# Input movie title for recommendation
input_title = 'Coco'

# Get the index of the input title in the dataset
title_idx = df[df['title'] == input_title].index[0]

# Recommend movies based on the input title using the decision tree model
recommended_movies = recommend_movies(input_title, decision_tree, count, label_encoder)

# Print the recommended movies
print(recommended_movies)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.471957 to fit
# 834                   The Little Mermaid Live!
# 519    Disney's Newsies: The Broadway Musical!
# Name: title, dtype: object

# %% [markdown]
# decision_tree.png is the visual decision tree

# %% [markdown]
# Decision Tree Evaluation

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load the dataset
df = pd.read_csv("/content/cleaned_dataset_disney.csv")

# Select relevant features for recommendation
features = ['plot', 'genre', 'actors', 'director']

# Drop rows with missing values in selected features
df = df.dropna(subset=features)

# Combine the features into a single column
df['combined_features'] = df[features].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Create the count matrix
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df['combined_features'])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(count_matrix, df['genre'], test_size=0.2, random_state=42)

# Create the decision tree classifier
decision_tree = DecisionTreeClassifier()

# Train the decision tree model
decision_tree.fit(X_train, y_train)

# Make predictions on the test set
y_pred = decision_tree.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print the evaluation metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.5
# Precision: 0.4266145436053902
# Recall: 0.5
# F1 Score: 0.44915156898852554
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# The decision tree model is trained to predict the genre of a movie based on its plot, actors, and director. The target variable is used to evaluate the performance of the decision tree model.

# %% [markdown]
# Bagging Algorithm with Evaluation

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load the dataset
df = pd.read_csv("/content/cleaned_dataset_disney.csv")

# Select relevant features for recommendation
features = ['plot', 'genre', 'actors', 'director']

# Drop rows with missing values in selected features
df = df.dropna(subset=features)

# Combine the features into a single column
df['combined_features'] = df[features].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Create the count matrix
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df['combined_features'])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(count_matrix, df['genre'], test_size=0.2, random_state=42)

# Create the base decision tree classifier
base_classifier = DecisionTreeClassifier()

# Create the Bagging classifier
bagging_classifier = BaggingClassifier(base_classifier, n_estimators=10, random_state=42)

# Train the Bagging classifier
bagging_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = bagging_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print the evaluation metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.5054347826086957
# Precision: 0.38870341614906834
# Recall: 0.5054347826086957
# F1 Score: 0.4256391052897985
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# Support Vector Machine (SVM) with Evaluation

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Load the dataset
df = pd.read_csv("/content/cleaned_dataset_disney.csv")

# Select relevant features for recommendation
features = ['plot', 'genre', 'actors', 'director']

# Drop rows with missing values in selected features
df = df.dropna(subset=features)

# Combine the features into a single column
df['combined_features'] = df[features].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Create the count matrix
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df['combined_features'])

# Create the SVM classifier
svm = SVC()

# Train the SVM model
svm.fit(count_matrix, df['genre'])

# Predict the genre of the input title
predicted_genre = svm.predict(count_matrix[df['title'] == input_title].toarray())[0]

# Print the predicted genre
print(predicted_genre)

# Evaluate the performance of the SVM model
accuracy = accuracy_score(df['genre'], svm.predict(count_matrix))
precision = precision_score(df['genre'], svm.predict(count_matrix), average='weighted')
recall = recall_score(df['genre'], svm.predict(count_matrix), average='weighted')

# Print the evaluation metrics
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
# Out:
# Animation, Adventure, Comedy, Family, Fantasy
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Accuracy: 0.6187363834422658
# Precision: 0.5559851433096923
# Recall: 0.6187363834422658

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
df = pd.read_csv('/content/cleaned_dataset_disney.csv')

# Select the features (independent variables) and target variable (dependent variable)
features = ['runtime', 'imdb_rating','metascore']
target = 'imdb_votes'

# Preprocess the imdb_votes column to remove commas
df['runtime'] = df['runtime'].str.extract('(\d+)').astype(float)

df['imdb_votes'] = df['imdb_votes'].str.replace(',', '').astype(float)

# Drop rows with missing values
df = df.dropna(subset=[*features, target])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 21438664476.465206
# Root Mean Squared Error (RMSE): 146419.48120542296
# R-squared (R2): 0.3939296639680778

# %% [markdown]
# Lasso and Ridge Regression

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
df = pd.read_csv('/content/cleaned_dataset_disney.csv')

# Select the features (independent variables) and target variable (dependent variable)
features = ['runtime', 'imdb_rating', 'metascore', ]
target = 'imdb_votes'

# Preprocess the imdb_votes column to remove commas
df['runtime'] = df['runtime'].str.extract('(\d+)').astype(float)
df['imdb_votes'] = df['imdb_votes'].str.replace(',', '').astype(float)

# Drop rows with missing values
df = df.dropna(subset=[*features, target])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Create linear regression models
linear_model = LinearRegression()
lasso_model = Lasso()
ridge_model = Ridge()

# Fit the models to the training data
linear_model.fit(X_train, y_train)
lasso_model.fit(X_train, y_train)
ridge_model.fit(X_train, y_train)

# Make predictions on the test data
y_pred_linear = linear_model.predict(X_test)
y_pred_lasso = lasso_model.predict(X_test)
y_pred_ridge = ridge_model.predict(X_test)

# Evaluate the models
mse_linear = mean_squared_error(y_test, y_pred_linear)
rmse_linear = mean_squared_error(y_test, y_pred_linear, squared=False)
r2_linear = r2_score(y_test, y_pred_linear)

mse_lasso = mean_squared_error(y_test, y_pred_lasso)
rmse_lasso = mean_squared_error(y_test, y_pred_lasso, squared=False)
r2_lasso = r2_score(y_test, y_pred_lasso)

mse_ridge = mean_squared_error(y_test, y_pred_ridge)
rmse_ridge = mean_squared_error(y_test, y_pred_ridge, squared=False)
r2_ridge = r2_score(y_test, y_pred_ridge)

# Print the evaluation metrics
print("Linear Regression:")
print("Mean Squared Error (MSE):", mse_linear)
print("Root Mean Squared Error (RMSE):", rmse_linear)
print("R-squared (R2):", r2_linear)
print("")

print("Lasso Regression:")
print("Mean Squared Error (MSE):", mse_lasso)
print("Root Mean Squared Error (RMSE):", rmse_lasso)
print("R-squared (R2):", r2_lasso)
print("")

print("Ridge Regression:")
print("Mean Squared Error (MSE):", mse_ridge)
print("Root Mean Squared Error (RMSE):", rmse_ridge)
print("R-squared (R2):", r2_ridge)
# Out:
# Linear Regression:
# Mean Squared Error (MSE): 21438664476.465206
# Root Mean Squared Error (RMSE): 146419.48120542296
# R-squared (R2): 0.3939296639680778
#
# Lasso Regression:
# Mean Squared Error (MSE): 21438674523.80962
# Root Mean Squared Error (RMSE): 146419.5155155542
# R-squared (R2): 0.39392937992998356
#
# Ridge Regression:
# Mean Squared Error (MSE): 21438901756.45384
# Root Mean Squared Error (RMSE): 146420.2914778339
# R-squared (R2): 0.3939229560706432

# %% [markdown]
# Improvement of Lasso and Ridge Regression using Iter

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = pd.read_csv('/content/cleaned_dataset_disney.csv')

# Select the features (independent variables) and target variable (dependent variable)
features = ['runtime', 'imdb_rating', 'metascore']
target = 'imdb_votes'

# Preprocess the imdb_votes column to remove commas
df['runtime'] = df['runtime'].str.extract('(\d+)').astype(float)
df['imdb_votes'] = df['imdb_votes'].str.replace(',', '').astype(float)

# Drop rows with missing values
df = df.dropna(subset=[*features, target])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create linear regression models
linear_model = LinearRegression()
lasso_model = Lasso(max_iter=1000)
ridge_model = Ridge(max_iter=1000)

# Fit the models to the scaled training data
linear_model.fit(X_train_scaled, y_train)
lasso_model.fit(X_train_scaled, y_train)
ridge_model.fit(X_train_scaled, y_train)

# Make predictions on the scaled test data
y_pred_linear = linear_model.predict(X_test_scaled)
y_pred_lasso = lasso_model.predict(X_test_scaled)
y_pred_ridge = ridge_model.predict(X_test_scaled)

# Evaluate the models
mse_linear = mean_squared_error(y_test, y_pred_linear)
rmse_linear = mean_squared_error(y_test, y_pred_linear, squared=False)
r2_linear = r2_score(y_test, y_pred_linear)

mse_lasso = mean_squared_error(y_test, y_pred_lasso)
rmse_lasso = mean_squared_error(y_test, y_pred_lasso, squared=False)
r2_lasso = r2_score(y_test, y_pred_lasso)

mse_ridge = mean_squared_error(y_test, y_pred_ridge)
rmse_ridge = mean_squared_error(y_test, y_pred_ridge, squared=False)
r2_ridge = r2_score(y_test, y_pred_ridge)

# Print the evaluation metrics
print("Linear Regression:")
print("Mean Squared Error (MSE):", mse_linear)
print("Root Mean Squared Error (RMSE):", rmse_linear)
print("R-squared (R2):", r2_linear)
print("")

print("Lasso Regression:")
print("Mean Squared Error (MSE):", mse_lasso)
print("Root Mean Squared Error (RMSE):", rmse_lasso)
print("R-squared (R2):", r2_lasso)
print("")

print("Ridge Regression:")
print("Mean Squared Error (MSE):", mse_ridge)
print("Root Mean Squared Error (RMSE):", rmse_ridge)
print("R-squared (R2):", r2_ridge)
# Out:
# Linear Regression:
# Mean Squared Error (MSE): 21438664476.465214
# Root Mean Squared Error (RMSE): 146419.48120542298
# R-squared (R2): 0.3939296639680776
#
# Lasso Regression:
# Mean Squared Error (MSE): 21438720513.70007
# Root Mean Squared Error (RMSE): 146419.672563833
# R-squared (R2): 0.3939280797973007
#
# Ridge Regression:
# Mean Squared Error (MSE): 21443219749.87753
# Root Mean Squared Error (RMSE): 146435.03593702408
# R-squared (R2): 0.39380088653929946

# %% [markdown]
# Univariate Selection of Linear Regression Creating Overfitting

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/cleaned_dataset_disney.csv')

# Select the features (independent variables) and target variable (dependent variable)
features = ['runtime', 'imdb_rating', 'metascore']
target = 'imdb_votes'

# Preprocess the imdb_votes column to remove commas
df['runtime'] = df['runtime'].str.extract('(\d+)').astype(float)
df['imdb_votes'] = df['imdb_votes'].str.replace(',', '').astype(float)

# Drop rows with missing values
df = df.dropna(subset=[*features, target])

# Calculate Pearson's correlation coefficient between features and target variable
correlation_matrix = df[features + [target]].corr()
correlation_with_target = correlation_matrix[target]
selected_features = correlation_with_target[correlation_with_target.abs() > 0.2].index.tolist()

# Split the data into training and testing sets using the selected features
X_train, X_test, y_train, y_test = train_test_split(df[selected_features], df[target], test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 1.1185590785834655e-20
# Root Mean Squared Error (RMSE): 1.0576195339456744e-10
# R-squared (R2): 1.0

# %% [markdown]
# Random Forest with Evaluation Metrics

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/cleaned_dataset_disney.csv')

# Select the features (independent variables) and target variable (dependent variable)
features = ['runtime', 'imdb_rating', 'metascore']
target = 'imdb_votes'

# Preprocess the imdb_votes column to remove commas
df['runtime'] = df['runtime'].str.extract('(\d+)').astype(float)
df['imdb_votes'] = df['imdb_votes'].str.replace(',', '').astype(float)

# Drop rows with missing values
df = df.dropna(subset=[*features, target])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Create a Random Forest regressor model
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 8199344344.273835
# Mean Absolute Error (MAE): 39700.59748146376
# R-squared (R2): 0.768204806440684

# %% [markdown]
# Testing Random Forest by adding categorical features

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/cleaned_dataset_disney.csv')

# Select the features (independent variables) and target variable (dependent variable)
numerical_features = ['runtime', 'imdb_rating', 'metascore']
categorical_features = ['genre', 'director', 'country', 'actors']
target = 'imdb_votes'

# Preprocess the runtime column to extract the numerical part
df['runtime'] = df['runtime'].str.extract('(\d+)').astype(float)

# Remove comma separators from imdb_votes column and convert to float
df['imdb_votes'] = df['imdb_votes'].str.replace(',', '').astype(float)

# Drop rows with missing values
df = df.dropna(subset=[*numerical_features, *categorical_features, target])

# Perform one-hot encoding on categorical features
df_encoded = pd.get_dummies(df, columns=categorical_features)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_encoded[numerical_features + df_encoded.columns[df_encoded.columns.str.startswith(categorical_features[0])].tolist()], df_encoded[target], test_size=0.2, random_state=42)

# Create a Random Forest regressor model
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)
print(y_pred)
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
# Out:
# [7.27530000e+02 2.46428000e+03 1.97284000e+03 7.25300000e+01
#  3.07587000e+04 4.78178333e+02 5.49146500e+04 4.80290360e+05
#  2.85050000e+02 5.59837667e+02 1.22155480e+05 2.82157333e+03
#  7.61274000e+03 5.01540000e+02 2.69485000e+03 7.10460000e+02
#  2.12375000e+03 5.00454000e+03 3.33773600e+03 8.16878700e+04
#  2.14989400e+04 1.93429000e+03 6.54008000e+03 1.64178900e+04
#  4.14411000e+03 2.00910090e+05 5.83950000e+02 1.03241000e+04
#  2.64511390e+05 3.76493200e+04 1.00000000e+01 5.29558350e+05
#  3.43805000e+02 7.16305000e+03 3.83766700e+04 2.66808600e+04
#  8.02651867e+03 3.99600000e+01 1.45727530e+05 2.76892900e+04
#  6.96047000e+03 3.91983000e+03 1.39595700e+04 3.08885400e+04
#  3.72982000e+03 2.05182000e+03 2.38524270e+05 7.29142000e+03
#  7.47070800e+05 6.72289020e+05 1.20896260e+05 1.36995000e+04
#  4.37723800e+05 3.58592000e+03 4.47493000e+03 6.38066000e+03
#  9.99373800e+04 1.11271000e+04 3.12974680e+05 1.93130000e+02
#  7.55958300e+04 4.57483333e+02 1.03373800e+04 1.75522000e+03
#  1.23710738e+03 6.93591150e+05 3.35122000e+03 1.33474730e+05
#  5.16315000e+03 9.15265000e+03 1.70409000e+03 4.88787000e+03
#  4.88616000e+02 2.03849000e+03 1.22694200e+04 2.27158300e+04
#  8.27008300e+04 3.99600000e+01 1.32121300e+05 6.24500000e+02
#  1.89363500e+03 3.23985000e+03 1.85676000e+03 2.49121000e+04
#  8.16778200e+04 2.93302800e+04 1.90924300e+04 1.11530000e+02
#  4.79527700e+04 7.95852000e+03 1.45920000e+03 2.60188000e+03
#  1.36156200e+04 1.00000000e+01 4.22522000e+03 6.32673333e+02
#  5.34703000e+03 4.69750000e+02 3.50013800e+04 3.00944000e+03
#  6.39338267e+03 1.00000000e+01 1.01393380e+05 1.91716000e+03
#  9.44020000e+02 1.27670000e+02 1.18966100e+04 2.84936667e+02
#  3.27009400e+04 1.01094600e+03 2.36077000e+03 7.49321870e+05
#  4.36331500e+04 4.46071700e+05 4.47899400e+04 3.53845000e+03
#  2.64311900e+04 1.56059000e+03 2.69718000e+03 3.74098370e+05
#  2.75757460e+05 2.36638300e+04 8.39500000e+02 1.00000000e+01
#  6.80231000e+03 4.09883400e+03 7.66180000e+03 5.11069900e+04
#  2.16500000e+01 6.54290000e+03 1.28630000e+02 1.00990000e+02
#  1.89433000e+03 9.38213770e+05 9.96719000e+03 3.09347000e+03
#  4.33808800e+04 9.04697900e+04 1.00000000e+01 3.25039300e+04
#  1.06874000e+03 1.27038320e+05 2.19803000e+03 5.90776333e+03
#  1.09857900e+04 3.91953500e+04 1.87228867e+03 2.53177500e+03
#  2.63750000e+02 6.13074000e+03 1.35563100e+04 3.25397000e+03
#  2.01500700e+04 2.49560100e+04 1.00000000e+01 5.89810000e+02
#  2.32796000e+03 2.32614000e+03 8.82261000e+03 6.87720000e+02
#  8.38330000e+02 8.68364000e+03 2.27197800e+04 4.83585619e+02
#  1.92261000e+03 1.34647000e+03 1.02013000e+04 8.71670000e+02
#  4.45451150e+05 6.35545167e+02 3.33516333e+03 3.09190000e+02
#  1.62180000e+03 6.38518300e+04 1.54308700e+04 1.02296000e+03
#  9.17330000e+02 1.39680000e+03 3.25936350e+03 6.80238000e+02
#  6.51960000e+03 6.09724000e+03 2.55633333e+01 5.41351780e+05]
# Mean Squared Error (MSE): 5336708857.073402
# Mean Absolute Error (MAE): 29933.698338768118
# R-squared (R2): 0.8491314170310528

# %% [markdown]
# Random Forest With imdb_votes and title mapping

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/cleaned_dataset_disney.csv')

# Select the features (independent variables) and target variable (dependent variable)
numerical_features = ['runtime', 'imdb_rating', 'metascore']
categorical_features = ['genre', 'director', 'country', 'actors']
target = 'imdb_votes'

# Preprocess the runtime column to extract the numerical part
df['runtime'] = df['runtime'].str.extract('(\d+)').astype(float)

# Remove comma separators from imdb_votes column and convert to float
df['imdb_votes'] = df['imdb_votes'].str.replace(',', '').astype(float)

# Drop rows with missing values
df = df.dropna(subset=[*numerical_features, *categorical_features, target])

# Perform one-hot encoding on categorical features
df_encoded = pd.get_dummies(df, columns=categorical_features)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_encoded[numerical_features + df_encoded.columns[df_encoded.columns.str.startswith(categorical_features[0])].tolist()], df_encoded[target], test_size=0.2, random_state=42)

# Create a Random Forest regressor model
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Get the movie titles from the test set
titles = df_encoded.loc[y_test.index, 'title'].values

# Create a DataFrame with predicted imdb_votes and corresponding movie titles
predictions = pd.DataFrame({'imdb_votes': y_pred, 'title': titles})

# Sort the predictions based on imdb_votes in descending order
predictions = predictions.sort_values('imdb_votes', ascending=False)

# Print the movie titles based on the predicted imdb_votes
print(predictions['title'].values)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
# Out:
# ['Star Wars: Episode IV - A New Hope' 'Captain America: Civil War'
#  'Inside Out' 'Avengers: Endgame' 'The Lion King' 'Iron Man'
#  'Star Wars: Episode VI - Return of the Jedi' 'Ratatouille'
#  'Star Wars: Episode I - The Phantom Menace' 'TRON: Legacy'
#  'Captain America: The First Avenger' 'The Nightmare Before Christmas'
#  "Disney's Newsies: The Broadway Musical!" 'Moana' 'TRON' 'Finding Dory'
#  'Big Hero 6' 'Monsters University' 'Bambi' 'The Princess and the Frog'
#  'Saving Mr. Banks' 'The Muppets' 'The Little Mermaid' 'Brave'
#  'Cinderella' 'The Princess Diaries 2: Royal Engagement'
#  'Remember the Titans' 'Secretariat' 'Robin Hood' 'Swiss Family Robinson'
#  'Bedknobs and Broomsticks' 'James and the Giant Peach' 'Cool Runnings'
#  "Blackbeard's Ghost" 'Monkey Kingdom' 'The Journey of Natty Gann'
#  'My Favorite Martian' 'Herbie Goes to Monte Carlo' 'The Game Plan'
#  'Blank Check' 'The Living Desert' 'Old Dogs' 'High School Musical 2'
#  'The Rocketeer' 'The Shaggy D.A.' 'The Computer Wore Tennis Shoes' 'Bolt'
#  'The Three Musketeers' 'Gus' 'The Cat from Outer Space' 'Big Business'
#  'Herbie Fully Loaded' 'Ice Princess'
#  'DuckTales the Movie: Treasure of the Lost Lamp' 'Invincible'
#  "Pooh's Heffalump Movie" 'Mars Needs Moms' 'The Thirteenth Year'
#  'What is Reading?' 'Partly Cloudy' 'Chicken Little' 'Piper' 'Valiant'
#  "Good Luck Charlie, It's Christmas!" "Doug's 1st Movie"
#  'Return to Halloweentown' 'Spider-Man: The Animated Series'
#  'Diana: In Her Own Words' "Mickey's Christmas Carol"
#  'Honey, I Shrunk the Kids' 'Lifted' 'Zapped' 'Oliver & Company'
#  'The Brave Little Toaster to the Rescue' 'Sydney to the Max'
#  'Honey, We Shrunk Ourselves!' 'Iron Man & Hulk: Heroes United'
#  'The Many Adventures of Winnie the Pooh'
#  "The Jungle Book: Mowgli's Story" 'Dinosaur' 'The Cheetah Girls 2'
#  'Wolverine and the X-Men' 'Peter Pan 2: Return to Never Land'
#  'Easter Island Underworld' 'The Incredible Dr. Pol'
#  'Diary of a Future President' 'Perri' 'The Suite Life Movie'
#  'Read It and Weep' 'The Imagineering Story' 'Kim Possible: So the Drama'
#  'One Man Band' 'Hatching Pete' 'Going to the Mat' 'Star Wars Rebels'
#  'Elephant' 'Ruby Bridges' 'Moon Mater' 'Alley Cats Strike' 'Super Rhino'
#  'Amphibia' 'Three Little Pigs' 'Camp Nowhere' 'Timon & Pumbaa'
#  'One Strange Rock' 'Rescue Squad Mater' 'Z-O-M-B-I-E-S'
#  'Inspector Gadget 2' "Red's Dream" 'Hannah Montana' 'Phineas and Ferb'
#  'Teen Beach Movie' 'The Christmas Star' 'Kim Possible'
#  'Stitch! The Movie' 'Andi Mack' "Don't Look Under the Bed" 'Teen Beach 2'
#  'Lonesome Ghosts' 'Homeward Bound II: Lost in San Francisco'
#  'The Castaway Cowboy' 'The Tortoise and the Hare' 'Iron Man' 'Jungle Cat'
#  'Austin & Ally' 'Buffalo Dreams' 'The Proud Family Movie'
#  "Donald's Dog Laundry" 'Trail of the Panda' 'Bearly Asleep'
#  'Miracle in Lane 2' 'The Luck of the Irish' 'Smart House'
#  '12 Dates of Christmas' 'Rip Girls' 'Jumping Ship'
#  'The Prince and the Pauper' 'Greyfriars Bobby: The True Story of a Dog'
#  "Don's Fountain of Youth" 'Get a Clue' 'Mickey Mouse Mixed-Up Adventures'
#  'Muppet Babies' 'Marvel Rising: Operation Shuri' 'Horse Sense'
#  'Marvel Rising: Battle of the Bands' 'Gordon Ramsay: Uncharted'
#  "Chip an' Dale" 'Stonehenge: Decoded' 'Henry Hugglemonster'
#  'Fantastic Four: The Animated Series' "Donald's Golf Game"
#  'The Big Bad Wolf' 'Dragon Around' "Olaf's Frozen Adventure" 'Annie'
#  'Disneyland Around the Seasons' "Mickey's Rival"
#  'The Adventures of Spin and Marty' 'How to Fish' 'Double Dribble'
#  'The Proud Family' 'Marvel Studios: Assembling a Universe' 'Gargoyles'
#  'Tangled: Before Ever After' 'Rocky Mountain Animal Rescue'
#  'Mickey Mouse Clubhouse' 'Hostile Planet' 'Phineas and Ferb: Star Wars'
#  'Year Million' 'Breaking2' 'Frank and Ollie' 'Rocket & Groot' 'Encore!'
#  'Origins: The Journey of Humankind' 'Man Among Cheetahs'
#  'Winged Seduction: Birds of Paradise' 'Unlikely Animal Friends'
#  "Marvel's Hero Project" 'Freaky Friday' 'Out There with Jack Randall'
#  'Freaky Friday' 'Freaky Friday' 'Bizarre Dinosaurs'
#  'Sharks of Lost Island']
# Mean Squared Error (MSE): 5336708857.073402
# Mean Absolute Error (MAE): 29933.698338768118
# R-squared (R2): 0.8491314170310528

# %% [markdown]
# Collaborative Filtering

# %%
# !pip install scikit-surprise
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.10.1)

# %%
import pandas as pd
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import cross_validate

# Load the dataset into a pandas DataFrame
data = pd.read_csv('/content/cleaned_dataset_disney.csv')

# Define the reader object to parse the ratings
reader = Reader(rating_scale=(1, 10))

# Load the dataset from the pandas DataFrame
dataset = Dataset.load_from_df(data[['title', 'metascore', 'imdb_rating']], reader)

# Define the collaborative filtering algorithm (KNNBasic)
algo = KNNBasic()

# Evaluate the algorithm using cross-validation
cross_validate(algo, dataset, measures=['RMSE', 'MAE'], cv=5, verbose=True)

# Train the algorithm on the full dataset
trainset = dataset.build_full_trainset()
algo.fit(trainset)

user_id = "End User"

k = 10
predictions = []
for movie_id in data['imdb_id'].unique():
    pred = algo.predict(user_id, movie_id)
    predictions.append((movie_id, pred.est))
    
# Sort the predictions by estimated rating (in descending order)
predictions.sort(key=lambda x: x[1], reverse=True)

# Retrieve the top-k recommended movies
top_k_recommendations = [movie_id for movie_id, _ in predictions[:k]]

# Print the top-k recommended movies
print(f"Top-{k} recommended movies")
for movie_id in top_k_recommendations:
    movie_title = data[data['imdb_id'] == movie_id]['title'].iloc[0]
    print(f"- {movie_title}")
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9448  1.0623  0.9899  0.9584  1.0773  1.0065  0.0539
# MAE (testset)     0.7392  0.8156  0.7544  0.7623  0.8332  0.7809  0.0367
# Fit time          0.01    0.01    0.01    0.01    0.01    0.01    0.00
# Test time         0.00    0.00    0.01    0.00    0.00    0.00    0.00
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Top-10 recommended movies
# - 10 Things I Hate About You
# - 101 Dalmatian Street
# - 101 Dalmatians
# - 101 Dalmatians 2: Patch's London Adventure
# - 102 Dalmatians
# - 12 Dates of Christmas
# - 20,000 Leagues Under the Sea
# - A Bug's Life
# - A Celebration of the Music from Coco
# - A Goofy Movie
